# %% [markdown]
# <a href="https://colab.research.google.com/github/luisorellana777/financial_fraud_anomaly_detection/blob/master/decision_tree_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Rapids library to work with GPU CUDA Nvidia

# %%
#!git clone https://github.com/rapidsai/rapidsai-csp-utils.git
#!python rapidsai-csp-utils/colab/pip-install.py nightlies nightlies

# %%
#%%time
#!pip install --target=/kaggle/working --extra-index-url=https://pypi.nvidia.com "cudf-cu12==24.12.*" "cuml-cu12==25.02.*"
#!rm -rf /kaggle/working/numpy*

# %%
#import cuml
#cuml.__version__

# %% [markdown]
# # RAPIDS imports

# %%
#from cuml.ensemble import RandomForestClassifier as DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier as DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ParameterGrid
import numpy as np
#import cupy as cp

# %% [markdown]
# # Support Vector Machine Trained With CUDA #
#
# Model creation and training

# %%
#import cuml
#from cuml.model_selection import GridSearchCV
from sklearn.metrics import f1_score
#import cudf
import numpy as np
import pandas as pd

from sklearn.model_selection import ParameterGrid
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import statsmodels.api as sm
import joblib
from scipy.stats import uniform
from sklearn import svm
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import make_blobs
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, recall_score, precision_score, classification_report, confusion_matrix, make_scorer, f1_score

# %%
df_original = pd.read_csv("/content/Synthetic_Financial_datasets_log.csv")

# %%
df_original['isFraud'] = df_original['isFraud'] | df_original['isFlaggedFraud']
df_original.drop(['isFlaggedFraud'], inplace=True, axis=1)

df = df_original.copy()

#convert categorical data to integers
le = LabelEncoder()
df['nameOrig'] = le.fit_transform(df['nameOrig'])
df['nameDest'] = le.fit_transform(df['nameDest'])
df['type'] = le.fit_transform(df['type']) # 0.0=CASH_IN; 0.25=CASH_OUT; 0.5=DEBIT; 0.75=PAYMENT; 1.0=TRANSFER

########### Data Preparation #################


# Removing Unessesary fields
df.drop(['nameOrig'], inplace=True, axis=1)
df.drop(['oldbalanceOrg'], inplace=True, axis=1)
df.drop(['newbalanceOrig'], inplace=True, axis=1)
df.drop(['oldbalanceDest'], inplace=True, axis=1)
df.drop(['newbalanceDest'], inplace=True, axis=1)
df.drop(['nameDest'], inplace=True, axis=1)
isFraud_field_no_normalise = df['isFraud']
df = df.drop('isFraud', axis = 1)

# normalize numbers in dataframe before joining one-hot encoded values
df = (df - df.min()) / (df.max() - df.min())

# separating feature variables and class variables
X = df
y = isFraud_field_no_normalise

# splitting the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

# %%
param_grid = {
    'max_depth': [15, 30],
    'max_features': [0.8, 0.9, 1.0],
    'criterion': ['gini', 'entropy'],
    'min_samples_leaf': [10, 25, 40, 60],
    'class_weight': [None, {0: 1, 1: 10}, {0: 1, 1: 50}, 'balanced'],
    'min_samples_split': [2, 10, 50, 100]
}

# Convert the parameter grid to a list of all combinations
grid = ParameterGrid(param_grid)

# Variable to store the best parameters and best score
best_params = None
best_score = 0

# Iterate through each parameter combination
for params in grid:
    print(f"Training with parameters: {params}")

    # Initialize the model with the current parameter combination
    model = DecisionTreeClassifier(
        max_depth=params['max_depth'],
        max_features=params['max_features'],
        criterion=params['criterion'],
        min_samples_leaf=params['min_samples_leaf'],
        class_weight=params['class_weight'],
        min_samples_split=params['min_samples_split'],
        random_state=42
    )

    # Fit the model
    model.fit(X_train, y_train)

    # Predict anomalies
    y_pred = model.predict(X_test)

    score = classification_report(y_test, y_pred, output_dict=True)['1']['f1-score']
    print(f"F1 Score for current parameters: {score}")

    if score > best_score:
        best_score = score
        best_model = model
        best_params = params
        print("\nBest Pre_Score:", best_score)
        print("\nBest Pre_Params:", best_params)
        joblib.dump(best_model, 'forest_pre_best_model.pkl')

# Display the best parameters and score
print("\nBest Parameters:", best_params)
print(f"Best Weighted F1-Score: {best_score:.4f}")

# Evaluate the best model
y_pred = best_model.predict(X_test)
joblib.dump(best_model, 'forest_best_model.pkl')

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Training with parameters: {'class_weight': None, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.41684598831847525
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.38903061224489793
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.38336
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.38336
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.38336
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.3628691983122363
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.38643634037108127
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.38643634037108127
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.38643634037108127
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.38643634037108127
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.5019785189372526
#
# Best Pre_Score: 0.5019785189372526
#
# Best Pre_Params: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 2}
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.5019785189372526
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.48903002309468824
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.46437994722955145
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.42429848905334566
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.42429848905334566
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.42429848905334566
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.4237599510104103
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.39390088945362134
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.39390088945362134
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.39390088945362134
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.3913732952743419
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.36893203883495146
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.36893203883495146
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.36893203883495146
# Training with parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.36893203883495146
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.3528778913394298
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.3528778913394298
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.3624091381100727
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.36320027411341443
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.36844716388291715
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.36844716388291715
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.36844716388291715
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.36348352387357097
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.33939010902196237
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.33939010902196237
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.33939010902196237
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.3108954289292423
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.33693101830126704
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.33693101830126704
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.33693101830126704
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.33693101830126704
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.3528778913394298
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.3528778913394298
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.3624091381100727
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.36320027411341443
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.36844716388291715
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.36844716388291715
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.36844716388291715
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.36348352387357097
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.33939010902196237
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.33939010902196237
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.33939010902196237
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.3108954289292423
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.33693101830126704
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.33693101830126704
# Training with parameters: {'class_weight': {0: 1, 1: 10}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.33693101830126704
# ...
# F1 Score for current parameters: 0.1439832368788665
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.1439832368788665
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.16082757044064697
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.1775049996551962
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.1775049996551962
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.1899902453665491
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.17896347548399974
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.15454026270702456
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.15454026270702456
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.15454026270702456
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.16433205991146685
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.1439832368788665
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.1439832368788665
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.1439832368788665
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.16082757044064697
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.15369217081850534
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.21886225043855986
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.21886225043855986
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.20579118469796628
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.19556113902847572
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.18723572938689217
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.18723572938689217
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.18723572938689217
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.1833557562944455
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.16600835766214436
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.16600835766214436
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.16600835766214436
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.16617992326633454
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.17041406295625766
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.17041406295625766
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.17041406295625766
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.17041406295625766
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.16102997694081475
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.16102997694081475
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.1373450619752099
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.13345380618929298
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.10663764961915125
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.10663764961915125
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.10663764961915125
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.10301075268817204
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.09201277955271565
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.09201277955271565
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.09201277955271565
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.09457719722422835
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.16102997694081475
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.16102997694081475
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 50}
# F1 Score for current parameters: 0.1373450619752099
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 10, 'min_samples_split': 100}
# F1 Score for current parameters: 0.13345380618929298
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 2}
# F1 Score for current parameters: 0.10663764961915125
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 10}
# F1 Score for current parameters: 0.10663764961915125
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 50}
# F1 Score for current parameters: 0.10663764961915125
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25, 'min_samples_split': 100}
# F1 Score for current parameters: 0.10301075268817204
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 2}
# F1 Score for current parameters: 0.09201277955271565
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 10}
# F1 Score for current parameters: 0.09201277955271565
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 50}
# F1 Score for current parameters: 0.09201277955271565
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40, 'min_samples_split': 100}
# F1 Score for current parameters: 0.09457719722422835
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 2}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 10}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 50}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60, 'min_samples_split': 100}
# F1 Score for current parameters: 0.11308075541652184
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 2}
# F1 Score for current parameters: 0.19644180874722017
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 10}
# F1 Score for current parameters: 0.19644180874722017
# Training with parameters: {'class_weight': {0: 1, 1: 50}, 'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10, 'min_samples_split': 50}

# %%
classification_report(y_test, y_pred, output_dict=True)['1']['f1-score']
