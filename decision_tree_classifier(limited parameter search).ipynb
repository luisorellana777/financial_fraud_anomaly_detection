# %% [markdown]
# ## Install Rapids library to work with GPU CUDA Nvidia

# %%
#!git clone https://github.com/rapidsai/rapidsai-csp-utils.git
#!python rapidsai-csp-utils/colab/pip-install.py nightlies nightlies

# %%
#%%time
#!pip install --target=/kaggle/working --extra-index-url=https://pypi.nvidia.com "cudf-cu12==24.12.*" "cuml-cu12==25.02.*"
#!rm -rf /kaggle/working/numpy*

# %%
#import cuml
#cuml.__version__

# %% [markdown]
# # RAPIDS imports

# %%
#from cuml.ensemble import RandomForestClassifier as DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier as DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ParameterGrid
import numpy as np
#import cupy as cp

# %% [markdown]
# # Support Vector Machine Trained With CUDA #
#
# Model creation and training

# %%
#import cuml
#from cuml.model_selection import GridSearchCV
from sklearn.metrics import f1_score
#import cudf
import numpy as np
import pandas as pd

from sklearn.model_selection import ParameterGrid
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import statsmodels.api as sm
import joblib
from scipy.stats import uniform
from sklearn import svm
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import make_blobs
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, recall_score, precision_score, classification_report, confusion_matrix, make_scorer, f1_score

# %%
df_original = pd.read_csv("/kaggle/input/synthetic-financial-datasets-log/Synthetic_Financial_datasets_log.csv")

# %%
df_original['isFraud'] = df_original['isFraud'] | df_original['isFlaggedFraud']
df_original.drop(['isFlaggedFraud'], inplace=True, axis=1)

df = df_original.copy()

#convert categorical data to integers
le = LabelEncoder()
df['nameOrig'] = le.fit_transform(df['nameOrig'])
df['nameDest'] = le.fit_transform(df['nameDest'])
df['type'] = le.fit_transform(df['type']) # 0.0=CASH_IN; 0.25=CASH_OUT; 0.5=DEBIT; 0.75=PAYMENT; 1.0=TRANSFER

########### Data Preparation #################


# Removing Unessesary fields
df.drop(['nameOrig'], inplace=True, axis=1)
df.drop(['oldbalanceOrg'], inplace=True, axis=1)
df.drop(['newbalanceOrig'], inplace=True, axis=1)
df.drop(['oldbalanceDest'], inplace=True, axis=1)
df.drop(['newbalanceDest'], inplace=True, axis=1)
df.drop(['nameDest'], inplace=True, axis=1)
isFraud_field_no_normalise = df['isFraud']
df = df.drop('isFraud', axis = 1)

# normalize numbers in dataframe before joining one-hot encoded values
df = (df - df.min()) / (df.max() - df.min())

# separating feature variables and class variables
X = df
y = isFraud_field_no_normalise

# splitting the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

# %%
param_grid = {
    'max_depth': [15, 30],
    'max_features': [0.8, 0.9, 1.0],
    'criterion': ['gini', 'entropy'],
    #'n_estimators': [100, 200, 300, 400, 500],
    'min_samples_leaf': [10, 25, 40, 60]
}

# Convert the parameter grid to a list of all combinations
grid = ParameterGrid(param_grid)

# Variable to store the best parameters and best score
best_params = None
best_score = 0

# Iterate through each parameter combination
for params in grid:
    print(f"Training with parameters: {params}")
    
    # Initialize the model with the current parameter combination
    model = DecisionTreeClassifier(
        max_depth=params['max_depth'],
        max_features=params['max_features'],
        criterion=params['criterion'],
        #n_estimators=params['n_estimators'],
        min_samples_leaf=params['min_samples_leaf'],
        random_state=42
    )
    
    # Fit the model
    model.fit(X_train, y_train)
    
    # Predict anomalies
    y_pred = model.predict(X_test)
    
    score = classification_report(y_test, y_pred, output_dict=True)['1']['f1-score']
    print(f"F1 Score for current parameters: {score}")
    
    if score > best_score:
        best_score = score
        best_model = model
        best_params = params
        print("\nBest Pre_Score:", best_score)
        print("\nBest Pre_Params:", best_params)
        joblib.dump(best_model, 'forest_pre_best_model.pkl')

# Display the best parameters and score
print("\nBest Parameters:", best_params)
print(f"Best Weighted F1-Score: {best_score:.4f}")

# Evaluate the best model
y_pred = best_model.predict(X_test)
joblib.dump(best_model, 'forest_best_model.pkl')

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.43256379100850545
#
# Best Pre_Score: 0.43256379100850545
#
# Best Pre_Params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10}
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.3765234124438742
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.38419530999036294
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.36821952776005107
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.43256379100850545
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.3765234124438742
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.38419530999036294
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.36821952776005107
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.46893317702227433
#
# Best Pre_Score: 0.46893317702227433
#
# Best Pre_Params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10}
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.41712877387553915
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.3760961351088016
# Training with parameters: {'criterion': 'gini', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.35375040943334424
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.42238267148014436
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.4111690702669531
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.3840304182509505
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.35424836601307186
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.42238267148014436
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.4111690702669531
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.3840304182509505
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.35424836601307186
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.4962920707358814
#
# Best Pre_Score: 0.4962920707358814
#
# Best Pre_Params: {'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10}
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.4212139791538933
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.3760961351088016
# Training with parameters: {'criterion': 'gini', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.35375040943334424
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.44093531733981167
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.40985651902682474
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.36955820702999037
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.8, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.34056541748849445
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.44093531733981167
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.40985651902682474
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.36955820702999037
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 0.9, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.34056541748849445
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.485862665897288
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.42033477991320517
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.3939008894536214
# Training with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.36945972177288905
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.44109671587827654
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.38500960922485583
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.34705301284162
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.3616042077580539
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.44109671587827654
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.38500960922485583
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.34705301284162
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 0.9, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.3616042077580539
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10}
# F1 Score for current parameters: 0.5016987542468857
#
# Best Pre_Score: 0.5016987542468857
#
# Best Pre_Params: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10}
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 25}
# F1 Score for current parameters: 0.4242984890533456
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 40}
# F1 Score for current parameters: 0.3939008894536214
# Training with parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 60}
# F1 Score for current parameters: 0.36945972177288905
#
# Best Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 10}
# Best Weighted F1-Score: 0.5017
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906351
#            1       0.81      0.36      0.50      2435
#
#     accuracy                           1.00   1908786
#    macro avg       0.90      0.68      0.75   1908786
# weighted avg       1.00      1.00      1.00   1908786

# %%
classification_report(y_test, y_pred, output_dict=True)['1']['f1-score']
# Out:
# 0.5016987542468857
